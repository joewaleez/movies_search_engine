# %% [markdown]
# # Professional Movie Search Engine
# Clean frontend + backend version of the project.

# %%
# !pip install streamlit pandas scikit-learn

# %% [markdown]
# ## Run Locally
# Use VS Code/CMD:
# ```bash
# pip install -r requirements.txt
# streamlit run app.py
# ```

# %% [markdown]
# ## Files
# - `backend/search_engine.py`: backend logic
# - `app.py`: frontend UI
# - `requirements.txt`: libraries
